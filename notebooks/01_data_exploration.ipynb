# %% [markdown]
# # 01 Data Exploration
#
# ## Objective
#
# This notebook performs initial exploratory data analysis (EDA) on the PCOS dataset before preprocessing and machine learning model development.
#
# The analysis includes:
#
# - inspecting dataset structure
# - checking feature types
# - identifying missing values
# - analysing class distribution
# - generating statistical summaries
# - visualising relationships between variables
#
# This stage helps identify potential data quality issues and patterns relevant to PCOS prediction.

# %%
# Import Required Libraries

# Used for handling and analysing tabular data
import pandas as pd

# Used for numerical operations and arrays
import numpy as np

# Used for creating graphs and visualisations
import matplotlib.pyplot as plt

# Provides cleaner and more advanced statistical visualisations
import seaborn as sns

# Helps manage file paths in a cleaner and more portable way
from pathlib import Path



# Display & Visual Settings


# Display all dataframe columns when viewing the dataset
pd.set_option("display.max_columns", None)

# Apply a cleaner visual style for plots and graphs
sns.set(style="whitegrid")

# %%
# Load the dataset from the raw data folder
DATA_PATH = Path("../data/raw/PCOS_data.csv")

# Read the CSV file into a pandas dataframe
df = pd.read_csv(DATA_PATH)

# Display the first 5 rows of the dataset
df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  \
# 0  19.3           15                78                22     10.48
# 1  24.9           15                74                20     11.70
# 2  25.3           11                72                18     11.80
# 3  29.7           13                72                20     12.00
# 4  20.1           11                72                18     10.00
#
#    Cycle(R/I)  Cycle length(days)  Marraige Status (Yrs)  Pregnant(Y/N)  \
# ...

# %%
# Display the number of rows and columns in the dataset
df.shape
# Out:
# (541, 45)

# %%
# Display dataset structure and data types
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3    Age (yrs)              541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   BMI                     541 non-null    float64
#  7   Blood Group             541 non-null    int64
#  8   Pulse rate(bpm)         541 non-null    int64
#  9   RR (breaths/min)        541 non-null    int64
#  10  Hb(g/dl)                541 non-null    float64
#  11  Cycle(R/I)              541 non-null    int64
#  12  Cycle length(days)      541 non-null    int64
#  13  Marraige Status (Yrs)   540 non-null    float64
# ...

# %%
# Generate descriptive statistics for numerical features
df.describe()
# Out:
#            Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# count  541.000000        541.000000  541.000000  541.000000   541.000000
# mean   271.000000        271.000000    0.327172   31.430684    59.637153
# std    156.317519        156.317519    0.469615    5.411006    11.028287
# min      1.000000          1.000000    0.000000   20.000000    31.000000
# 25%    136.000000        136.000000    0.000000   28.000000    52.000000
# 50%    271.000000        271.000000    0.000000   31.000000    59.000000
# 75%    406.000000        406.000000    1.000000   35.000000    65.000000
# max    541.000000        541.000000    1.000000   48.000000   108.000000
#
#        Height(Cm)          BMI  Blood Group  Pulse rate(bpm)   \
# count   541.000000  541.000000   541.000000        541.000000
# mean    156.484835   24.307579    13.802218         73.247689
# std       6.033545    4.055129     1.840812          4.430285
# ...

# %%
# Check for missing values in each column
df.isnull().sum()
# Out:
# Sl. No                      0
# Patient File No.            0
# PCOS (Y/N)                  0
#  Age (yrs)                  0
# Weight (Kg)                 0
# Height(Cm)                  0
# BMI                         0
# Blood Group                 0
# Pulse rate(bpm)             0
# RR (breaths/min)            0
# Hb(g/dl)                    0
# Cycle(R/I)                  0
# Cycle length(days)          0
# Marraige Status (Yrs)       1
# Pregnant(Y/N)               0
# No. of abortions            0
#   I   beta-HCG(mIU/mL)      0
# II    beta-HCG(mIU/mL)      0
# FSH(mIU/mL)                 0
# LH(mIU/mL)                  0
# FSH/LH                      0
# Hip(inch)                   0
# Waist(inch)                 0
# Waist:Hip Ratio             0
# TSH (mIU/L)                 0
# AMH(ng/mL)                  0
# PRL(ng/mL)                  0
# Vit D3 (ng/mL)              0
# PRG(ng/mL)                  0
# RBS(mg/dl)                  0
# Weight gain(Y/N)            0
# ...

# %%
# Sort missing values from highest to lowest
missing_values = df.isnull().sum().sort_values(ascending=False)

# Display only columns with missing values
missing_values[missing_values > 0]
# Out:
# Unnamed: 44              539
# Marraige Status (Yrs)      1
# Fast food (Y/N)            1
# dtype: int64

# %%
# Display class distribution for PCOS diagnosis
df["PCOS (Y/N)"].value_counts()
# Out:
# PCOS (Y/N)
# 0    364
# 1    177
# Name: count, dtype: int64

# %%
# Create a visualisation of PCOS class distribution
plt.figure(figsize=(6,4))

sns.countplot(data=df, x="PCOS (Y/N)")

# Add graph title and labels
plt.title("Distribution of PCOS Diagnosis")
plt.xlabel("PCOS Diagnosis")
plt.ylabel("Number of Patients")

# Display the graph
plt.show()

# %%
# Generate a correlation matrix for numerical features
correlation_matrix = df.corr(numeric_only=True)

# Display correlation heatmap
plt.figure(figsize=(18,12))

sns.heatmap(
    correlation_matrix,
    cmap="coolwarm",
    annot=False
)

# Add title
plt.title("Correlation Heatmap of Numerical Features")

# Display heatmap
plt.show()

# %%
# Calculate correlations with the PCOS target variable
pcos_correlations = correlation_matrix["PCOS (Y/N)"].sort_values(ascending=False)

# Display correlations with PCOS
pcos_correlations
# Out:
# PCOS (Y/N)                1.000000
# Follicle No. (R)          0.648327
# Follicle No. (L)          0.603346
# Skin darkening (Y/N)      0.475733
# hair growth(Y/N)          0.464667
# Weight gain(Y/N)          0.441047
# Cycle(R/I)                0.401644
# Fast food (Y/N)           0.377933
# Pimples(Y/N)              0.286077
# Weight (Kg)               0.211938
# BMI                       0.199697
# Hair loss(Y/N)            0.172879
# Waist(inch)               0.164598
# Hip(inch)                 0.162297
# Avg. F size (L) (mm)      0.132992
# Endometrium (mm)          0.106648
# Avg. F size (R) (mm)      0.097690
# Pulse rate(bpm)           0.091821
# Hb(g/dl)                  0.087170
# Vit D3 (ng/mL)            0.085494
# Height(Cm)                0.068254
# Reg.Exercise(Y/N)         0.065337
# LH(mIU/mL)                0.063879
# Sl. No                    0.060998
# Patient File No.          0.060998
# RBS(mg/dl)                0.048922
# BP _Diastolic (mmHg)      0.038032
# ...

# %%
# Select the top correlations with PCOS (excluding the target itself)
top_correlations = pcos_correlations[1:11]

# Create bar chart of top correlated features
plt.figure(figsize=(10,6))

top_correlations.plot(kind="bar")

# Add title and labels
plt.title("Top Features Correlated with PCOS")
plt.xlabel("Features")
plt.ylabel("Correlation Coefficient")

# Rotate feature labels for readability
plt.xticks(rotation=45)

# Display the graph
plt.show()

# %%
# Check exact column names
df.columns.tolist()
# Out:
# ['Sl. No',
#  'Patient File No.',
#  'PCOS (Y/N)',
#  ' Age (yrs)',
#  'Weight (Kg)',
#  'Height(Cm) ',
#  'BMI',
#  'Blood Group',
#  'Pulse rate(bpm) ',
#  'RR (breaths/min)',
#  'Hb(g/dl)',
#  'Cycle(R/I)',
#  'Cycle length(days)',
#  'Marraige Status (Yrs)',
#  'Pregnant(Y/N)',
#  'No. of abortions',
#  '  I   beta-HCG(mIU/mL)',
#  'II    beta-HCG(mIU/mL)',
#  'FSH(mIU/mL)',
#  'LH(mIU/mL)',
#  'FSH/LH',
#  'Hip(inch)',
#  'Waist(inch)',
#  'Waist:Hip Ratio',
#  'TSH (mIU/L)',
#  'AMH(ng/mL)',
#  'PRL(ng/mL)',
#  'Vit D3 (ng/mL)',
#  'PRG(ng/mL)',
#  'RBS(mg/dl)',
#  'Weight gain(Y/N)',
#  'hair growth(Y/N)',
#  'Skin darkening (Y/N)',
#  'Hair loss(Y/N)',
#  'Pimples(Y/N)',
#  'Fast food (Y/N)',
#  'Reg.Exercise(Y/N)',
#  'BP _Systolic (mmHg)',
#  'BP _Diastolic (mmHg)',
#  'Follicle No. (L)',
#  'Follicle No. (R)',
#  'Avg. F size (L) (mm)',
#  'Avg. F size (R) (mm)',
#  'Endometrium (mm)',
#  'Unnamed: 44']

# %%
# Select important numerical features
selected_features = [
    "BMI",
    "Weight (Kg)",
    " Age (yrs)",
    "LH(mIU/mL)",
    "FSH(mIU/mL)"
]

# Create histograms for selected features
df[selected_features].hist(
    figsize=(12, 8),
    bins=20
)

plt.suptitle("Distribution of Important Numerical Features")
plt.show()

# %%
# Create boxplots to identify potential outliers
plt.figure(figsize=(14,6))

sns.boxplot(data=df[selected_features])

# Add title and rotate labels
plt.title("Boxplots of Important Numerical Features")

plt.xticks(rotation=45)

# Display visualisation
plt.show()

# %%
# Display the highest LH values
df["LH(mIU/mL)"].sort_values(ascending=False).head()
# Out:
# 455    2018.00
# 120      14.69
# 328      14.24
# 153      12.95
# 449      12.04
# Name: LH(mIU/mL), dtype: float64

# %%
# Display the highest FSH values
df["FSH(mIU/mL)"].sort_values(ascending=False).head()
# Out:
# 329    5052.00
# 250      65.40
# 281      60.37
# 412      40.08
# 195      22.00
# Name: FSH(mIU/mL), dtype: float64

# %%
# Display rows with extreme LH values
df[df["LH(mIU/mL)"] > 100]
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 455     456               456           1          32         52.0
#
#      Height(Cm)    BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  \
# 455        150.0  23.1           13                70                18
#
#      Hb(g/dl)  Cycle(R/I)  Cycle length(days)  Marraige Status (Yrs)  \
# 455       9.4           2                   5                   12.0
#
#      Pregnant(Y/N)  No. of abortions    I   beta-HCG(mIU/mL)  \
# 455              0                 0                  272.78
#
#     II    beta-HCG(mIU/mL)  FSH(mIU/mL)  LH(mIU/mL)  FSH/LH  Hip(inch)  \
# 455                   1.99         4.33      2018.0     0.0         36
#
#      Waist(inch)  Waist:Hip Ratio  TSH (mIU/L) AMH(ng/mL)  PRL(ng/mL)  \
# 455           32             0.89          2.1        7.7       40.47
#
#      Vit D3 (ng/mL)  PRG(ng/mL)  RBS(mg/dl)  Weight gain(Y/N)  \
# ...

# %%
# Display rows with extreme FSH values
df[df["FSH(mIU/mL)"] > 100]
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 329     330               330           0          29         53.0
#
#      Height(Cm)    BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  \
# 329        161.0  20.4           15                72                18
#
#      Hb(g/dl)  Cycle(R/I)  Cycle length(days)  Marraige Status (Yrs)  \
# 329      10.2           2                   6                    5.0
#
#      Pregnant(Y/N)  No. of abortions    I   beta-HCG(mIU/mL)  \
# 329              1                 0                   900.6
#
#     II    beta-HCG(mIU/mL)  FSH(mIU/mL)  LH(mIU/mL)   FSH/LH  Hip(inch)  \
# 329                  900.6       5052.0        3.68  1372.83         38
#
#      Waist(inch)  Waist:Hip Ratio  TSH (mIU/L) AMH(ng/mL)  PRL(ng/mL)  \
# 329           35             0.92         0.83        3.5       30.58
#
#      Vit D3 (ng/mL)  PRG(ng/mL)  RBS(mg/dl)  Weight gain(Y/N)  \
# ...
